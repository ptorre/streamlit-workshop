# %% [markdown]
# # Code Organization
#
# I have put all the data-related code into a new file called `backend.py`. The file is a series of functions (e.x. `get_data()`). Among other things, this makes it easier to do your own analysis in a notebook. Below is an example of using it:

# %%
import backend as be

be.get_unique_states()

# %% [markdown]
# # Notebook Exercise for `backend.py`
#
# 1. Open `backend.py` and familiarize yourself with the code.
# 2. Use it to create a map of `Median Household Income` for 2005.
# 3. Use it to create a map of `Median Household Income` for 2023.
# 4. How are the maps different? How are they the same?
#
# Note that by having the code to create a map in a separate function, it is easier to create multiple maps.

# %%
# Create the 2005 map here

# %%
# Create the 2023 map here

# %% [markdown]
# # App Exercise for `backend.py`
#
# Update `organization_app.py` so that it calls as many functions from the backend as possible. You'll need to add `import backend as be` to the top of the file.
#
# When you are done, you should be able to remove the imports for `pandas` and `plotly.express` from the file.
