# %% [markdown]
# # Jupyter Notebook Review
#
# **Exercise 1**: Click the "Play" icon next to the cell below to execute the code and see its output. This is the dataset we will be using throughout the course.

# %%
import pandas as pd

df = pd.read_csv('state_data.csv')

df

# %% [markdown]
# **Exercise 2**: Click the "Play" icon next to the cell below to generate a boxplot of Total Population. What is the median value?
#
# This cell uses Plotly Express to generate the graph. Note that the graph is interactive. We will be using Plotly Express throughout this course.

# %%
import plotly.express as px

px.box(df['Total Population'])

# %% [markdown]
# **Exercise 3**: Add a new cell below this one by hovering your mouse just beneath the cell-then click the "+" icon that appears. In the new cell, copy the code from above and modify it to plot a boxplot of `Median Household Income`. Then run the cell.
